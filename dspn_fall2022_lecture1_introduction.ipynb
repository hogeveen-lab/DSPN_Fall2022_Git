# %% [markdown]
# # Data Science in Psychology & Neuroscience (DSPN):
#
# ## Lecture 1. Introduction
#
# ### Date: August 23, 2022

# %% [markdown]
# # Syllabus
#
# ## General information
#
# __Credits:__ 3 <br>
# __Semester Offering:__ Fall, 2022 <br>
# __Class location and time:__ Logan Hall 125, TR 11:00 AM — 12:15 PM <br>
#
# ## Instructor information
#
# __Instructor:__ Dr. Jeremy Hogeveen <br>
# __Email:__ jhogeveen@unm.edu <br>
# __Office location & hours:__ By Appointment
#
# ## Course content
#
# __All of the course materials will be uploaded to this GIT repository:__
#
# * <a href="https://github.com/hogeveen-lab/DSPN_Fall2022_git">DSPN Fall 2022 Github</a>
#
# __There is no official textbook. But, here is a list of things I used for inspiration in organizing the course:__
#
# * <a href="https://uk.sagepub.com/en-gb/eur/computational-neuroscience-and-cognitive-modelling/book238062">Computational Neuroscience & Cognitive Modeling</a>
# * <a href="https://cogs18.github.io">UCSD COG Intro to Python</a>
# * <a href="https://datascienceinpractice.github.io/docs/index.html">Data Science in Practice</a>
# * <a href="https://r4ds.had.co.nz">Data Science in R</a>
# * <a href="http://math.ecnu.edu.cn/~lfzhou/seminar/%5BJoel_Grus%5D_Data_Science_from_Scratch_First_Princ.pdf">Data Science from Scratch</a>
# * <a href="https://github.com/jlord/git-it-electron#what-to-install">Git-It Github training</a>
# * <a href="https://learning.oreilly.com/library/view/the-art-of/9781449318482/pr03.html">The Art of Readable Code</a>
#
# ## Why are we here?
#
# 1. To provide some of the scaffolding needed to become excellent and efficient data scientists, including computer programming, data wrangling, and data exploration & analysis.
# 2. To provide BOTH i) a soft landing for psychology and neuroscience trainees who are very new to programming, AND ii) an opportunity for more advanced coders to further hone / develop their skills.
#
# ## Specific learning objectives:
# 1. Proficiency in Python and R programming languages.
# 2. Efficient and effective data wrangling skills.
# 3. Advanced data visualization capabilities.
# 4. Introduction to advanced data modeling and prediction.
#
# ## Tentative outline -- Note: Revised August 31, 2022
# | ClassNum | Session | Date | Topic | Assignments |
# | :---: | :---: | :---: | :---: | :---: |
# | 1 | wk1_ses1 | 8/23 | Introduction pt. i |  |
# | 2 | wk1_ses2 | 8/25 | Introduction pt. ii |  |
# | 3 | wk2_ses1 | 8/30 | Iteration pt. i |  |
# | 4 | wk2_ses2 | 9/1 | Iteration pt. ii |  |
# | 5 | wk3_ses1 | 9/6 | Iteration pt. iii |  |
# | 6 | wk3_ses2 | 9/8 |  Conditionals pt. i  | |
# | 7 | wk4_ses1 | 9/13 | Conditionals pt. ii | Assignment 1 Due |
# | 8 | wk4_ses2 | 9/15 | Conditionals pt. iii  |  |
# | 9 | wk5_ses1 | 9/20 |  Harmonic Oscillator Debrief |  |
# | 10 | wk5_ses2 | 9/22 | Functions |  |
# | 11 | wk6_ses1 | 9/27 | Data Wrangling pt. i | Assignment 2 Due |
# | 12 | wk6_ses2 | 9/29 | Data Wrangling pt. ii |  |
# | 13 | wk7_ses1 | 10/4 | Integrate-and-Fire Debrief Visualization pt. i |  |
# | 14 | wk7_ses2 | 10/6 | Data Wrangling pt. iii |  |
# | 15 | wk8_ses1 | 10/11 | Visualization pt. i |  |
# | 16 | wk8_ses2 | 10/13 | Fall Break NO CLASS | Assignment 3 Due |
# | 17 | wk9_ses1 | 10/18 | Visualization pt. ii |  |
# | 18 | wk9_ses2 | 10/20 | Visualization pt. iii |  |
# | 19 | wk10_ses1 | 10/25 | Data Wrangling Debrief |  |
# | 20 | wk10_ses2 | 10/27 | Statistical Modeling pt. i  | Assignment 4 Due |
# | 21 | wk11_ses1 | 11/1 | Statistical Modeling pt. ii |  |
# | 22 | wk11_ses2 | 11/3 | Statistical Modeling pt. iii |  |
# | 23 | wk12_ses1 | 11/8 | Data Visualization Debrief |  |
# | 24 | wk12_ses2 | 11/10 | Final Assignment Discussion | |
# | 25 | wk13_ses1 | 11/15 | INSTRUCTOR GONE (SfN) | Assignment 5 Due |
# | 26 | wk13_ses2 | 11/17 | INSTRUCTOR GONE (SfN) |  |
# | 27 | wk14_ses1 | 11/22 | Final Assignment Working Session i |  |
# | 28 | wk14_ses2 | 11/24 | Thanksgiving Holiday |  |
# | 29 | wk15_ses1 | 11/29 | Final Assignment Working Session ii |  |
# | 30 | wk15_ses2 | 12/1 | Final Assignment Working Session iii |  |
# | 31-32 | wks14-16 | 12/2—12/17 | Class Done, Independent Work | Final assignment (before 12/17) |
#
# ## Submitting assignments -- Note: Revised August 31, 2022
# * Assignment 1: <a href="https://www.dropbox.com/request/6xn5dVMbckJnyq61RPvd">Oscillator</a> (before 9/13, 23:00 MDT)
# * Assignment 2: <a href="https://www.dropbox.com/request/wSQY5MGqmDtx9iLrsSBb">Integrate & Fire</a> (before 9/27, 23:00 MDT)
# * Assignment 3: <a href="https://www.dropbox.com/request/5tyrxS7O80R8XD2qLbx5">Data Wrangling</a> (before 10/13, 23:00 MDT)
# * Assignment 4: <a href="https://www.dropbox.com/request/TRf86lmPH0wBHcq8GdSG">Data Visualization</a> (before 10/27, 23:00 MDT)
# * Assignment 5: <a href="https://www.dropbox.com/request/yieJlRt7WYzOpWvkUJ0S">Statistical Modeling</a> (before 11/15, 23:00 MDT)
# * Final assignment: <a href="https://www.dropbox.com/request/B1EOzfP3KOpV7iBf6gaY">Final Project</a> (before 12/17, 23:00 MDT)
#
# ## Grades
# * Assignments 1-5: 12% each (60% of grade)
# * Final Assignment: 20%
# * Participation: 20%
#
# ### Notes on grades:
#
# * Assignments will be 80% "did you try," and 20% driven by the quality of the submission.
# * Participation will be 80% "did you come to class," and 20% asking and answering questions.

# %% [markdown]
# # Section 1: Data Science Preamble
#
# ## What is Data Science?
#
# <img src="img/what_is_ds.png" width="600">
#
# ## Why take the time to learn DS skills?
#
# Practical: Help your research computing
# * Accelerate knowledge discovery
# * Improve data intuitions
# * Minimize human error
#
# Pragmatic: Average salary (e.g. in ABQ)
# * Postdoc=\$47k
# * Data Scientist=\$92k

# %% [markdown]
# # Section 2: How Will Things Work?
#
# ## What will you do in class?
#
# __Write stuff on a computer, while also having Zoom open__
#
# 1. Zoom + code open on same monitor (ctrl/cmd+tab)
# 2. External monitor or two computers
# 3. Phone zoom and code on computer
#
# ## Software & Languages
#
# __Will provide exposure to four things:__
#
# * JupyterLab
# * Python
# * R
#
# __Python, in particular, can be a mess to install and make sure you have all the packages you need.__
#
# <img src="img/python_superfund.png" width="350">
#
# ## Anaconda
#
# __So, we will use the prepackaged distribution that comes with <a href="https://www.anaconda.com">Anaconda</a>__
#
# <img src="img/anaconda.png" width="350">
#
# * Once installed, should have the core computing library we need for Jupyter, Python, and R.
#
# ## JupyterLab
#
# __<a href="https://jupyter.org">The Jupyter project</a> enables us to blend markdown chunks (i.e., what you're reading now 😀), chunks of code, and code outputs.__
#
# <img src="img/jupyter.png" width="350">
#
# * Jupyter Notebooks are the individual files we work on to merge text, code, etc.
#     * For more info: <a href="https://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html">What is Jupyter?</a>
# * JupyterLab is more of an Integrated Development Environment (IDE), I use it. You can do everything you need in notebook though.
#
# ## Python
#
# __<a href="https://www.python.org">Python</a> is a general purpose, open source language, with a strong developer community building & sharing new tools everyday.__
#
# <img src="img/python3.jpg" width="350">
#
# * Really cool sunglasses people use it for everything they do.
# * For data visualization and modeling, I typically prefer R.
#
# ## R
#
# __<a href="https://www.r-project.org">The R Project for Statistical Computing</a> is specifically tailored to data cleaning, statistical analysis, and data visualization.__
#
# <img src="img/Rlogo.png" width="350">
#
# ### If you're left thinking...
#
# <img src="img/swanson.gif" width="350">
#
# ### Just remember...
#
# * For this week, all you need to do is download <a href="https://www.anaconda.com">Anaconda</a>.
# * We will work through the software, languages, and assignments together, one week at a time.
