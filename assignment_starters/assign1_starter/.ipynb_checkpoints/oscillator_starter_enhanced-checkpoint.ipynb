# %% [markdown]
# # Assignment #1: Oscillator
# ## DSPN, Fall 2022
# ### Jeremy Hogeveen (jhogeveen@unm.edu)
#
# * This is the starter script to program a HARMONIC oscillator
#     * For a challenge, script both a HARMONIC and DAMPED oscillator
#     * There are myriad ways to do it. This is ONE example, feel free to explore others.

# %% [markdown]
# ### PREAMBLE: set the constants and initial values

# %%
import matplotlib.pyplot as plt # data plotting package that works nicely with pandas

# constants
P = 20
delta_t = 0.05

# initial values
t = 0
s = 1
a = -1 * P * s
v = 0

# change values
delta_v = a * delta_t
delta_s = (v + delta_v) * delta_t

# %% [markdown]
# ### Now, using a FOR loop to simulate harmonic oscillator's motion

# %%
s_to_plot = [] # note, this code stores / appends to a list. Many other options!
for i in range(200):
    # update time, position, and velocity
    t += ??
    s += ??
    v += ??
    # updating derivative values for a, delta_v, and delta_s
    a = a_formula
    delta_v = delta_v_formula
    delta_s = delta_s_formula
    # storing the updated position in a list
    s_to_plot.append(s)

# %% [markdown]
# ### Now, we are ready to take a stab at plotting the harmonic oscillator

# %%
plt.plot(s_to_plot)
plt.ylabel('position')
plt.show()
